# %%
# Data cleaning for demo of difference-in-differences estimation w/ machine learning methods
# data from "Do Police Reduce Crime? Estimates Using the Allocation of Police Forces After a Terrorist Attack" Rafael Di Tella 
# https://www.aeaweb.org/articles?id=10.1257/000282804322970733

# %%
import pandas as pd
import numpy as np
import pyreadstat

# %%
cbb, _ = pyreadstat.read_dta('CrimebyBlock.dta')
panel, _ = pyreadstat.read_dta('MonthlyPanel.dta')
# Out:
# <ipython-input-66-ff31ce430198>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cbb, _ = pyreadstat.read_dta('CrimebyBlock.dta')
# <ipython-input-66-ff31ce430198>:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   panel, _ = pyreadstat.read_dta('MonthlyPanel.dta')

# %%
panel = panel.merge(cbb[['observ','educjefe','ocupado']], on='observ') # education of head of household, unemployment rate

# %%
panel
# Out:
#       observ    barrio            calle altura  institu1  institu3  distanci  \
# 0      870.0      Once          Cordoba  a2300       0.0       1.0       1.0
# 1      870.0      Once          Cordoba  a2300       0.0       1.0       1.0
# 2      870.0      Once          Cordoba  a2300       0.0       1.0       1.0
# 3      870.0      Once          Cordoba  a2300       0.0       1.0       1.0
# 4      870.0      Once          Cordoba  a2300       0.0       1.0       1.0
# ...      ...       ...              ...    ...       ...       ...       ...
# 9631   140.0  Belgrano  Virrey del Pino  a1600       0.0       0.0       3.0
# 9632   140.0  Belgrano  Virrey del Pino  a1600       0.0       0.0       3.0
# 9633   140.0  Belgrano  Virrey del Pino  a1600       0.0       0.0       3.0
# 9634   140.0  Belgrano  Virrey del Pino  a1600       0.0       0.0       3.0
# 9635   140.0  Belgrano  Virrey del Pino  a1600       0.0       0.0       3.0
#
#       edpub  estserv  banco  totrob   mes   educjefe   ocupado
# 0       1.0      0.0    0.0    0.00   4.0  10.846611  0.949495
# 1       1.0      0.0    0.0    0.00   5.0  10.846611  0.949495
# 2       1.0      0.0    0.0    0.00   6.0  10.846611  0.949495
# 3       1.0      0.0    0.0    0.00   7.0  10.846611  0.949495
# 4       1.0      0.0    0.0    0.00   8.0  10.846611  0.949495
# ...     ...      ...    ...     ...   ...        ...       ...
# 9631    0.0      0.0    0.0    0.25  10.0  12.771961  0.950423
# 9632    0.0      0.0    0.0    0.00  11.0  12.771961  0.950423
# 9633    0.0      0.0    0.0    0.00  12.0  12.771961  0.950423
# 9634    0.0      0.0    0.0    0.00  72.0  12.771961  0.950423
# 9635    0.0      0.0    0.0    0.00  73.0  12.771961  0.950423
#
# [9636 rows x 14 columns]

# %%
panel = panel.drop(columns=['altura','institu3','distanci']) # unsure what these are

# %%
english_translation = {'observ': 'block',
                      'barrio': 'neighbourhood',
                      'calle': 'street',
                      'institu1': 'jewish_insitute',
                       'edpub': 'public_institution',
                       'estserv': 'gas_station',
                       'banco': 'bank',
                       'totrob': 'car_thefts',
                       'mes': 'month',
                       'educjefe': 'education',
                       'ocupado': 'employment_rate'
                      }
panel = panel.rename(columns=english_translation)

# %%
panel.to_csv("DiTella_crime.csv", index=False)
